# %% [markdown]
# # While-loop
#
# With the help of the code, the loop with the condition is written as follows:
#
# ```
# while <condition>:
#    <instructions>
# ```
# As long as the condition is met, the instructions are repeated
#
# ### Example:
# (It iterates 5 times, until i=5, then it exits the loop)

# %%
i = 0
while i < 5:
    print(i)
    i += 1
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# We can use boolean variable as a flag variable — with a value other than "yes", it signals the loop to stop:

# %%
hungry = input("R u hungry? (y/n)")

while hungry == "y":
    print("Eat 1 more pancake")
    hungry = input("R u hungry? (y/n)")

print("Finally, get some rest")
# Out:
# Eat 1 more pancake
# Eat 1 more pancake
# Eat 1 more pancake
# Eat 1 more pancake
# Finally, get some rest

# %% [markdown]
# We can limit the number of iterations using several conditions:
#
# Imagine we have only 5 pancakes...

# %%
n_pancakes = 5
n_eaten = 0
hungry = input("R u hungry? (y/n)")

while n_eaten < n_pancakes and hungry == "y":
    print("Eat 1 more pancake")
    n_eaten += 1
    hungry = input("R u hungry? (y/n)")

print(f'You have eaten {n_eaten} pancakes')
# Out:
# Eat 1 more pancake
# Eat 1 more pancake
# Eat 1 more pancake
# You have eaten 3 pancakes

# %% [markdown]
# ### Warning
#
# If you forget to change your flag variable or for some other reason the condition always returns True, the loop will be infinite. Then just stop the code and correct the mistake.
#
# ### If-else in a while-loop
#
# We can also check for some condition in the loop body

# %%
n_pancakes = 5
n_eaten = 0
hungry = input("R u hungry? (y/n)")

while n_eaten < n_pancakes and hungry == "y":
    print("Eat 1 more pancake")
    n_eaten += 1

    if n_eaten == int(0.5 * n_pancakes):
        print("You have eaten half the pancakes. Stop.")

    hungry = input("R u hungry? (y/n)")

print(f'You have eaten {n_eaten} pancakes')
# Out:
# Eat 1 more pancake
# Eat 1 more pancake
# You have eaten half the pancakes. Stop.
# Eat 1 more pancake
# Eat 1 more pancake
# Eat 1 more pancake
# You have eaten 5 pancakes

# %% [markdown]
# ### While True - break variation
#
# We can also use "break" to exit the loop

# %%
n_pancakes = 5
n_eaten = 0
hungry = input("R u hungry? (y/n)")

while True:
    if n_eaten == n_pancakes or hungry != "y":
        break
    
    print("Eat 1 more pancake")
    n_eaten += 1

    if n_eaten == int(0.5 * n_pancakes):
        print("You have eaten half the pancakes. Stop.")

    hungry = input("R u hungry? (y/n)")

print(f'You have eaten {n_eaten} pancakes')
# Out:
# Eat 1 more pancake
# Eat 1 more pancake
# You have eaten half the pancakes. Stop.
# Eat 1 more pancake
# Eat 1 more pancake
# Eat 1 more pancake
# You have eaten 5 pancakes

# %% [markdown]
# While-loop can be used to get multiple variables from keyboard

# %%
# Out:
# You've entered: 1
# You've entered: 4
# You've entered: 3
# You've entered: 6
# You've entered: 1
# You've entered: 0
# [1, 4, 3, 6, 1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
